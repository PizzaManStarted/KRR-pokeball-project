# %%
# %pip install matplotlib
# %pip install ipympl
# to interact  with plot
# %matplotlib widget
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2


import cuboid_plots
import random

# Import libraries
import matplotlib.pyplot as plt
import json
import random as random
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker as ticker
import numpy as np
import math
import os
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Settings

# %%
sphere_file = os.path.join("outputs", "sphere.db")
cuboid_file = os.path.join("outputs", "cuboids.db")
sol_file = os.path.join("outputs", "sol.json")

# %%
radius = cuboid_plots.read_sphere_radius(sphere_file)
plt.close()

generated_cuboid_map, cuboid_color_map = cuboid_plots.generated_cuboid_map_id(cuboid_file)
sphere_data, color_sphere_data = cuboid_plots.get_sphere_data(sol_file, radius, cuboid_color_map)

cuboids_data, cuboids_color_data = cuboid_plots.get_cuboids_data(cuboid_file, generated_cuboid_map, cuboid_color_map, radius)

# %%
fig = plt.figure()
axe = fig.add_subplot(111, projection='3d')

cuboid_plots.plot_data(fig, axe, sphere_data, color_sphere_data, radius)

# %%
cols = 2
rows = math.ceil(len(cuboid_color_map) / cols)


fig = plt.figure(figsize=(4*cols, 4*rows))

for i in range(len(cuboid_color_map)):
    axe = fig.add_subplot(rows, cols, i+1, projection='3d')

    axe.set_title(f"Cuboid {i + 1}")

    cuboid_plots.plot_data(fig, axe, cuboids_data[i], cuboids_color_data[i], radius, True)
